# %%
# !pip install -q lucid>=0.2.3

# %%
import numpy as np

import ctypes.util
from lucid.misc.gl.glcontext import create_opengl_context

# Now it's safe to import OpenGL and EGL functions
import OpenGL.GL as gl
from OpenGL.GLU import *

# create_opengl_context() creates GL context that is attached to an
# offscreen surface of specified size. Note that rendering to buffers
# of different size and format is still possible with OpenGL Framebuffers.
#
# Users are expected to directly use EGL calls in case more advanced
# context management is required.
WIDTH, HEIGHT = 800,600
create_opengl_context((WIDTH, HEIGHT))
    
# OpenGL context is available here.

print(gl.glGetString(gl.GL_VERSION))
print(gl.glGetString(gl.GL_VENDOR)) 
#print(gl.glGetString(gl.GL_EXTENSIONS))
# Out:
# ---------------------------------------------------------------------------
# EGLError                                  Traceback (most recent call last)
# <ipython-input-20-b4b0804a8a03> in <cell line: 17>()
#      15 # context management is required.
#      16 WIDTH, HEIGHT = 800,600
# ---> 17 create_opengl_context((WIDTH, HEIGHT))
#      18
#      19 # OpenGL context is available here.
#
# /usr/local/lib/python3.9/dist-packages/lucid/misc/gl/glcontext.py in create_opengl_context(surface_size)
#      89
#      90   major, minor = egl.EGLint(), egl.EGLint()
# ---> 91   egl.eglInitialize(egl_display, pointer(major), pointer(minor))
#      92
#      93   config_attribs = [
#
# /usr/local/lib/python3.9/dist-packages/OpenGL/error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     228                 err = self._currentChecker()
#     229                 if err != self._noErrorResult:
# --> 230                     raise self._errorClass(
#     231                         err,
#     232                         result,
#
# EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglInitialize,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x7f35e31be040>,
# 		<OpenGL.arrays.arraydatatype.LP_c_int object at 0x7f35e31be340>,
# 		<OpenGL.arrays.arraydatatype.LP_c_int object at 0x7f35e31be3c0>,
# 	),
# 	result = 0
# )

# %%
# Let's render something!
gl.glClear(gl.GL_COLOR_BUFFER_BIT

# %%
from IPython.display import display
from PIL import Image

img_buf = gl.glReadPixelsub(0, 0, WIDTH, HEIGHT, gl.GL_RGB, gl.GL_UNSIGNED_BYTE)
img = np.frombuffer(img_buf,np.uint8).reshape(HEIGHT, WIDTH, 3)[::-1]
display(Image.fromarray(img,'RGB'))

# %%
# Let's render something!
gl.glClear(gl.GL_COLOR_BUFFER_BIT)
gl.glPointSize(5)



gl.glColor3f(10,0,0)
gl.glBegin(gl.GL_POINTS)
gl.glVertex2f(.0,.08 )
gl.glVertex2f(.04, .0 )
gl.glVertex2f(.04, 0)
gl.glVertex2f(-.04, 0)
gl.glVertex2f(-.04,0 )
gl.glVertex2f(0, .08)

import random
for i in range(50):
  x = random.randint(-100,100)/100
  y = random.randint(-100,100)/100
  gl.glVertex2f(x, y)
gl.glEnd()

# %%
img_buf = gl.glReadPixelsub(0, 0, WIDTH, HEIGHT, gl.GL_RGB, gl.GL_UNSIGNED_BYTE)
img = np.frombuffer(img_buf,np.uint8).reshape(HEIGHT, WIDTH, 3)[::-1]
display(Image.fromarray(img,'RGB'))

# %%
gl.glClear(gl.GL_COLOR_BUFFER_BIT)
gl.glPointSize(5)

#ROOF
gl.glColor3f(10,0,0)
gl.glBegin(gl.GL_TRIANGLES)
gl.glVertex2f(.0,.8 )
gl.glVertex2f(.4, .0 )
#gl.glVertex2f(.4, 0)
#gl.glVertex2f(-.4, 0)
gl.glVertex2f(-.4,0 )
#gl.glVertex2f(0, .8)

gl.glEnd()
#ROOM
gl.glBegin(gl.GL_LINES)
gl.glVertex2f(-.4, 0)
gl.glVertex2f(-.4, -.8)
gl.glVertex2f(.4, 0)
gl.glVertex2f(.4, -.8)
gl.glVertex2f(-.4, -.8)
gl.glVertex2f(.4, -.8)

gl.glEnd()
#Window
gl.glBegin(gl.GL_LINES)
gl.glVertex2f(-.1, -.1)
gl.glVertex2f(-.1, -.3)
gl.glVertex2f(-.3, -.1)
gl.glVertex2f(-.1, -.1)
gl.glVertex2f(-.3, -.1)
gl.glVertex2f(-.3, -.3)
gl.glVertex2f(-.3, -.3)
gl.glVertex2f(-.1, -.3)

gl.glEnd()
#Window
gl.glBegin(gl.GL_LINES)
gl.glVertex2f(.1, -.1)
gl.glVertex2f(.1, -.3)
gl.glVertex2f(.3, -.1)
gl.glVertex2f(.1, -.1)
gl.glVertex2f(.3, -.1)
gl.glVertex2f(.3, -.3)
gl.glVertex2f(.3, -.3)
gl.glVertex2f(.1, -.3)
gl.glEnd()

#Door
gl.glBegin(gl.GL_LINES)

gl.glVertex2f(-.2, -.4)
gl.glVertex2f(.2, -.4)

gl.glVertex2f(.2, -.8)
gl.glVertex2f(.2, -.4)

gl.glVertex2f(-.2, -.8)
gl.glVertex2f(-.2, -.4)

gl.glEnd()

gl.glBegin(gl.GL_POINTS)
gl.glVertex2f(-.1, -.6)
gl.glEnd()

# %%
img_buf = gl.glReadPixelsub(0, 0, WIDTH, HEIGHT, gl.GL_RGB, gl.GL_UNSIGNED_BYTE)
img = np.frombuffer(img_buf,np.uint8).reshape(HEIGHT, WIDTH, 3)[::-1]
display(Image.fromarray(img,'RGB'))
